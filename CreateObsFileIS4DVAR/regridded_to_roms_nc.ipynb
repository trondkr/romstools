# %%
import xarray as xr
import matplotlib

# Read the file with data
with xr.open_dataset('copernicus_regridded.nc') as ds:
        ds = ds      
ds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Downloads/anaconda3/envs/romstools/lib/python3.9/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/Downloads/anaconda3/envs/romstools/lib/python3.9/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x7f2bb4981a60>, ('/home/lisapro/Documents/workdir/romstools/CreateObsFileIS4DVAR/copernicus_regridded.nc',), 'r', (('mmap', None), ('version', 2))]
#
# During handling of the above exception, another exception occurred:
#
# ...
